# %% [markdown]
# <a href="https://colab.research.google.com/github/mithon-research/Practice-/blob/main/Python_Basics_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calling Function:(Arguments)
def greet (name):
  print ("Hello" , name)
greet ("Jhon")
# Out:
# Hello Jhon

# %%
# Function with 2 argument
def add_numbers(num1, num2):
    sum = num1 + num2
    print ("Sum: ", sum)

add_numbers (5,6)
# Out:
# Sum:  11

# %%
#function defination
def find_square (num) :
    result = num * num
    return result

square = find_square (5)
print ("sqare: ", square)
# Out:
# sqare:  25

# %%
#default argument
def greet (name, message= "Hello"):
    print (message,name)
greet ("alice", "good morning")
greet ("Bob")
# Out:
# good morning alice
# Hello Bob

# %%
#function of sum any number of arguments

def add_all (*numbers):
  return sum (numbers)

print (add_all(1, 2, 3, 4 ))
# Out:
# 10

# %%
#function to print keywords arguments

def greet (**words):
    for key , value in words. items():
        print (f"{key}: {value}")

greet(name = "jhon", greeting = "Hello")
# Out:
# name: jhon
# greeting: Hello

# %%
#local variable

def greet():
    message = 'Hello'
    print ('local', message)
greet()

print(message)
# Out:
# local Hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2028/468711783.py in <cell line: 0>()
#       6 greet()
#       7
# ----> 8 print(message)
#
# NameError: name 'message' is not defined

# %%
#global variable

message = 'hello'
def greet():
    print ("local", message)
greet()
print('glbal', message)
# Out:
# local hello
# glbal hello

# %%
#nonlocal variable

def outer ():
    message = 'local'
    def inner():
        nonlocal message
        message = 'nonlocal'
        print ("inner:", message)
    inner ()
    print ("outer:", message)
outer()
# Out:
# inner: nonlocal
# outer: nonlocal

# %%
#global variable

c= 1
def add():
    global c
    c=c+2
    print (c)
add()
# Out:
# 3

# %%
#number of prime

def is_prime (n):

  if n <=1:
      return False
  for i in range (2, int(n**0.5)+1):
      if n % i==0:
           return False
  return True
number =29
print (f" is {number}prime ? {is_prime(number)}")
# Out:
#  is 29prime ? True

# %%
#common divisor

def gcd (a,b):
    while b:
        a, b =b, a % b
    return a
num1 , num2 = 40,10
print (f" GCD of {num1} and {num2} is {gcd(num1, num2)}")
# Out:
#  GCD of 40 and 10 is 10

# %%
#sum of digits

def sum_of_digits (n):
    total = 0
    while n > 0:
        total += n % 10
        n//=10
    return total


number = 1234
print(f" sum of digits of {number}is {sum_of_digits (number)}")
# Out:
#  sum of digits of 1234is 10

# %%
#longest word

def longest_word (sentence):
    words = sentence . split ()
    longest = max(words , key=len)

    return longest
sentence = "the quick brown fox jumps over the lazy dog"
print (f" the longest word in the sentence is: '{longest_word(sentence)}'")
# Out:
#  the longest word in the sentence is: 'quick'

# %%
#area of circle

import math
def area_of_circle (radius):
    return math.pi * (radius ** 2)

radius = 5
print (f" area of the circle with radius {radius} is: {area_of_circle (radius)}")
# Out:
#  area of the circle with radius 5 is: 78.53981633974483
