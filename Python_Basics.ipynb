# %% [markdown]
# <a href="https://colab.research.google.com/github/mithon-research/Practice-/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Python Basic**

# %%
# HW1 Subtraction, Multiplication and Division.

print("Welcome")
print("Summation of Solar and Wind output power is:",15+20,"MW","\nSubtraction:",200-100,"\nMultiplication",15*20,"\nDivision",15/5,"\t Summary of the result is:","Good")
# Out:
# Welcome
# Summation of Solar and Wind output power is: 35 MW
# Subtraction: 100
# Multiplication 300
# Division 3.0 	 Summary of the result is: Good

# %%
#Assignment operator

num1 =100
num2 =200
result = num1 + num2 #Assignment operator
div = num1 / num2
res = num1 % num2
print("summation =", result)
print("Division =", div)
print("Reminder =", res)
# Out:
# summation = 300
# Division = 0.5
# Reminder = 100

# %%
## Input int.

num1 = int(input("Enter the number:"))
num2 = int(input("Enter the number"))
print("result :",num1+num2)
# Out:
# Enter the number:100
# Enter the number200
# result : 300

# %%
# Formatting Print

num1 = 120.20
num2 = 100.10
sum = num1 + num2
print ("Result: {:.1f}%" .format(sum))
print ("Modify: {:.3f}" .format(sum))
# Out:
# Result: 220.3%
# Modify: 220.300

# %%
## condition 1

num = 1001
if num % 2 == 0: #condition
 print("Yes, this is the even number")

if num % 2 == 1: #condition
 print("This is the ODD Number")
# Out:
# This is the ODD Number

# %%
## condition 2

num1 = 200
num2 = 100
num3 = 500

if num1>num2 and num1>num3:
  print (num1,"is Greater")

elif num2>num and num2>num3:
  print(num2,"is Greater")

else:print(num3,"is Greater")
# Out:
# 500 is Greater

# %%
## comparison operator

a=20
b=30

print (a==b)
# Out:
# False

# %%
## Logical operator

a=True
b=True
c=False

print (a and b and c)
print (a and not c)
# Out:
# False
# True

# %%
## Printing different types of values

print("Skill, Morph")  # Displaying a string

name = "Mr. Person"
age = 21
print("Name:", name, "Age:", age)

num1 = 5
num2 = 7
print("Num1 =", num1, "Num2 =", num2, "Sum =", num1 + num2)  # Printing variables and literals
# Out:
# Skill, Morph
# Name: Mr. Person Age: 21
# Num1 = 5 Num2 = 7 Sum = 12

# %%
dept = "Machine Learning" ##Assign value to variable
org = "Skill Morph"

print(dept)
# Out:
# Machine Learning

# %%
dept, org, batch = "Machine Learning", "Skill Morph", 1 ##Decalare multiple variables in a line

print(dept, "\t", org, "\t", batch)
# Out:
# Machine Learning 	 Skill Morph 	 1

# %%
## H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.

# %%
# Changing value of a variable

dept_name = 'Machine Learning'
print("Before: ", dept_name)

dept_name = 'Data Science'  # assigning a new value to dept_name

print("After: ", dept_name)
# Out:
# Before:  Machine Learning
# After:  Data Science

# %%
## H3: Write a program to change values of an integer variable

# %%
# Variables and literals

num = 123.56

b = False

print(b)
# Out:
# False

# %%
# Implicit Type Conversion

num1 = 12345 #integer
num2 = 5000.6789 #float

sum = num1 + num2

print(sum)

print(type(num1), type(num2), type(sum))
# Out:
# 17345.6789
# <class 'int'> <class 'float'> <class 'float'>

# %%
# Explicit Type Conversion

num1 = 12345 #integer
num2 = 5000.6789 #float

sum = num1 + int(num2)

print(num2)

print(sum)

print(type(num1), type(num2), type(sum))
# Out:
# 5000.6789
# 17345
# <class 'int'> <class 'float'> <class 'int'>

# %%
## H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.

# %%
# Input from users

age = input() #Default: String

print(age, type(age))

age = float(input())
print(age)
# Out:
# 12
# 12 <class 'str'>
# 12
# 12.0

# %%
## Arithmatic Operator

a = int(input('Enter the first number: '))
b = int(input('Enter the first number: '))

print('Sum: ', a + b)  # Addition
print('Subtraction: ', a - b)  # Subtraction
print('Multiplication: ', a * b)  # Multiplication
print('Division: ', a / b)  # Division
print('Floor Division: ', a // b)  # Floor division
print('Modulo: ', a % b)  # Modulo
print('Power: ', a ** b)  # a to the power b
# Out:
# Enter the first number: 12
# Enter the first number: 2
# Sum:  14
# Subtraction:  10
# Multiplication:  24
# Division:  6.0
# Floor Division:  6
# Modulo:  0
# Power:  144

# %%
## H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.

# %%
## Comparison Operator

a = 10
b = 20

print(a == b)
# Out:
# False

# %%
## Logical Operators

a = True
b = True
c = False

print (a and b and c)

print(a and not b)
# Out:
# False
# False

# %%
## Bitwise Operators

a = 5 # 101
b = 6 # 110

print(a & b) # 100
# Out:
# 4

# %% [markdown]
# ## **Python Flow Control**

# %%
## Even or Odd

num = 10

if num % 2 == 0: #Inportant to understand the condition
  print("Even")
# Out:
# Even

# %%
## H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.

# %%
## H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

# %%
## H9: Write a program that asks the user to enter three numbers and determines which one is the largest.

# %% [markdown]
# ## **Loops**

# %%
## For Loop
## print 1 to 100

for x in range (1,6,2):
  print(x)
  print ("Skill Morph")
# Out:
# 1
# Skill Morph
# 3
# Skill Morph
# 5
# Skill Morph

# %%
## while loop

x = 0

while x < 5:
  print(x)
  x = x + 1
print("Skill Morph")
# Out:
# 0
# 1
# 2
# 3
# 4
# Skill Morph

# %%
# H10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.

# %%
# H11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.

# %%
# H12: Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop.

# %% [markdown]
# # **Thank You!**
